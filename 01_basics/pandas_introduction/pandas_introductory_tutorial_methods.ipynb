# %% [markdown]
# # Python Introductory Tutorial - The Series Data Structure

# %%
import pandas as pd
pd.Series?

# %%
animals = ['Tiger', 'Bear', 'Moose']
pd.Series(animals)
# Out:
# 0    Tiger
# 1     Bear
# 2    Moose
# dtype: object

# %%
numbers = [1, 2, 3]
pd.Series(numbers)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
animals = ['Tiger', 'Bear', None]
pd.Series(animals)
# Out:
# 0    Tiger
# 1     Bear
# 2     None
# dtype: object

# %%
numbers = [1, 2, None]
pd.Series(numbers)
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64

# %%
import numpy as np
np.nan == None
# Out:
# False

# %%
np.nan == np.nan
# Out:
# False

# %%
np.isnan(np.nan)
# Out:
# True

# %%
sports = {'Archery': 'Bhutan',
          'Golf': 'Scotland',
          'Sumo': 'Japan',
          'Taekwondo': 'South Korea'}
s = pd.Series(sports)
s
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# dtype: object

# %%
s.index
# Out:
# Index(['Archery', 'Golf', 'Sumo', 'Taekwondo'], dtype='object')

# %%
s = pd.Series(['Tiger', 'Bear', 'Moose'], index=['India', 'America', 'Canada'])
s
# Out:
# India      Tiger
# America     Bear
# Canada     Moose
# dtype: object

# %%
sports = {'Archery': 'Bhutan',
          'Golf': 'Scotland',
          'Sumo': 'Japan',
          'Taekwondo': 'South Korea'}
s = pd.Series(sports, index=['Golf', 'Sumo', 'Hockey'])
s
# Out:
# Golf      Scotland
# Sumo         Japan
# Hockey         NaN
# dtype: object

# %% [markdown]
# # Querying a Series

# %%
sports = {'Archery': 'Bhutan',
          'Golf': 'Scotland',
          'Sumo': 'Japan',
          'Taekwondo': 'South Korea'}
s = pd.Series(sports)
s
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# dtype: object

# %%
s.iloc[3]
# Out:
# 'South Korea'

# %%
s.loc['Golf']
# Out:
# 'Scotland'

# %%
s[3]
# Out:
# 'South Korea'

# %%
s['Golf']
# Out:
# 'Scotland'

# %%
sports = {99: 'Bhutan',
          100: 'Scotland',
          101: 'Japan',
          102: 'South Korea'}
s = pd.Series(sports)

# %%
#s[0] #This won't call s.iloc[0] as one might expect, it generates an error instead

# %%
s = pd.Series([100.00, 120.00, 101.00, 3.00])
s
# Out:
# 0    100.0
# 1    120.0
# 2    101.0
# 3      3.0
# dtype: float64

# %%
total = 0
for item in s:
    total+=item
print(total)
# Out:
# 324.0

# %%
import numpy as np

total = np.sum(s)
print(total)
# Out:
# 324.0

# %%
#this creates a big series of random numbers
s = pd.Series(np.random.randint(0,1000,10000))
s.head()
# Out:
# 0    352
# 1    364
# 2    319
# 3    982
# 4      1
# dtype: int64

# %%
len(s)
# Out:
# 10000

# %%
# %%timeit -n 100
summary = 0
for item in s:
    summary+=item
# Out:
# 1.47 ms ± 296 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit -n 100
summary = np.sum(s)
# Out:
# 77.5 µs ± 7.06 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
s+=2 #adds two to each item in s using broadcasting
s.head()
# Out:
# 0    354
# 1    366
# 2    321
# 3    984
# 4      3
# dtype: int64

# %%
for label, value in s.iteritems():
    s.at[label]=value+2    
s.head()
# Out:
# 0    356
# 1    368
# 2    323
# 3    986
# 4      5
# dtype: int64

# %%
# %%timeit -n 10
s = pd.Series(np.random.randint(0,1000,10000))
for label, value in s.iteritems():
    s.loc[label]= value+2
# Out:
# 706 ms ± 146 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit -n 10
s = pd.Series(np.random.randint(0,1000,10000))
s+=2
# Out:
# 1.02 ms ± 296 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
s = pd.Series([1, 2, 3])
s.loc['Animal'] = 'Bears'
s
# Out:
# 0             1
# 1             2
# 2             3
# Animal    Bears
# dtype: object

# %%
original_sports = pd.Series({'Archery': 'Bhutan',
                             'Golf': 'Scotland',
                             'Sumo': 'Japan',
                             'Taekwondo': 'South Korea'})
cricket_loving_countries = pd.Series(['Australia',
                                      'Barbados',
                                      'Pakistan',
                                      'England'], 
                                   index=['Cricket',
                                          'Cricket',
                                          'Cricket',
                                          'Cricket'])
all_countries = original_sports.append(cricket_loving_countries)

# %%
original_sports
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# dtype: object

# %%
cricket_loving_countries
# Out:
# Cricket    Australia
# Cricket     Barbados
# Cricket     Pakistan
# Cricket      England
# dtype: object

# %%
all_countries
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# Cricket        Australia
# Cricket         Barbados
# Cricket         Pakistan
# Cricket          England
# dtype: object

# %%
all_countries.loc['Cricket']
# Out:
# Cricket    Australia
# Cricket     Barbados
# Cricket     Pakistan
# Cricket      England
# dtype: object

# %% [markdown]
# # The DataFrame Data Structure

# %%
import pandas as pd
purchase_1 = pd.Series({'Name': 'Chris',
                        'Item Purchased': 'Dog Food',
                        'Cost': 22.50})
purchase_2 = pd.Series({'Name': 'Kevyn',
                        'Item Purchased': 'Kitty Litter',
                        'Cost': 2.50})
purchase_3 = pd.Series({'Name': 'Vinod',
                        'Item Purchased': 'Bird Seed',
                        'Cost': 5.00})
df = pd.DataFrame([purchase_1, purchase_2, purchase_3], index=['Store 1', 'Store 1', 'Store 2'])
df.head()
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5
# Store 2  Vinod      Bird Seed   5.0

# %%
df.loc['Store 2']
# Out:
# Name                  Vinod
# Item Purchased    Bird Seed
# Cost                    5.0
# Name: Store 2, dtype: object

# %%
type(df.loc['Store 2'])
# Out:
# pandas.core.series.Series

# %%
df.loc['Store 1']
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5

# %%
df.loc['Store 1', 'Cost']
# Out:
# Store 1    22.5
# Store 1     2.5
# Name: Cost, dtype: float64

# %%
df.T
# Out:
#                  Store 1       Store 1    Store 2
# Name               Chris         Kevyn      Vinod
# Item Purchased  Dog Food  Kitty Litter  Bird Seed
# Cost                22.5           2.5        5.0

# %%
df.T.loc['Cost']
# Out:
# Store 1    22.5
# Store 1     2.5
# Store 2     5.0
# Name: Cost, dtype: object

# %%
df['Cost']
# Out:
# Store 1    22.5
# Store 1     2.5
# Store 2     5.0
# Name: Cost, dtype: float64

# %%
df.loc['Store 1']['Cost']
# Out:
# Store 1    22.5
# Store 1     2.5
# Name: Cost, dtype: float64

# %%
df.loc[:,['Name', 'Cost']]
# Out:
#           Name  Cost
# Store 1  Chris  22.5
# Store 1  Kevyn   2.5
# Store 2  Vinod   5.0

# %%
df.drop('Store 1')
# Out:
#           Name Item Purchased  Cost
# Store 2  Vinod      Bird Seed   5.0

# %%
df
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5
# Store 2  Vinod      Bird Seed   5.0

# %%
copy_df = df.copy()
copy_df = copy_df.drop('Store 1')
copy_df
# Out:
#           Name Item Purchased  Cost
# Store 2  Vinod      Bird Seed   5.0

# %%
copy_df.drop?

# %%
del copy_df['Name']
copy_df
# Out:
#         Item Purchased  Cost
# Store 2      Bird Seed   5.0

# %%
df['Location'] = None
df
# Out:
#           Name Item Purchased  Cost Location
# Store 1  Chris       Dog Food  22.5     None
# Store 1  Kevyn   Kitty Litter   2.5     None
# Store 2  Vinod      Bird Seed   5.0     None

# %% [markdown]
# # Dataframe Indexing and Loading

# %%
costs = df['Cost']
costs
# Out:
# Store 1    22.5
# Store 1     2.5
# Store 2     5.0
# Name: Cost, dtype: float64

# %%
costs+=2
costs
# Out:
# Store 1    24.5
# Store 1     4.5
# Store 2     7.0
# Name: Cost, dtype: float64

# %%
df
# Out:
#           Name Item Purchased  Cost Location
# Store 1  Chris       Dog Food  24.5     None
# Store 1  Kevyn   Kitty Litter   4.5     None
# Store 2  Vinod      Bird Seed   7.0     None

# %%
# !cat olympics.csv
# Out:
# cat: olympics.csv: No such file or directory

# %%
df = pd.read_csv('../python_introduction/data/titanic.csv', index_col = 0, skiprows=1)
df.head()
# Out:
#    3    male  22.0  1  0.1     7.25  S  Third    man   True Unnamed: 11  \
# 0
# 1  1  female  38.0  1    0  71.2833  C  First  woman  False           C
# 1  3  female  26.0  0    0   7.9250  S  Third  woman  False         NaN
# 1  1  female  35.0  1    0  53.1000  S  First  woman  False           C
# 0  3    male  35.0  0    0   8.0500  S  Third    man   True         NaN
# 0  3    male   NaN  0    0   8.4583  Q  Third    man   True         NaN
#
#    Southampton   no  False
# 0
# 1    Cherbourg  yes  False
# 1  Southampton  yes   True
# 1  Southampton  yes  False
# 0  Southampton   no   True
# 0   Queenstown   no   True

# %%
df = pd.read_csv('../python_introduction/data/titanic.csv')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
for col in df.columns:
    if col[:2]=='su':
        df.rename(columns={col:'First' + col[4:]}, inplace=True)
    if col[:2]=='pc':
        df.rename(columns={col:'Second' + col[4:]}, inplace=True)
    if col[:2]=='se':
        df.rename(columns={col:'Third' + col[4:]}, inplace=True)
    if col[:1]=='f':
        df.rename(columns={col:'#' + col[1:]}, inplace=True) 

df.head()
# Out:
#    Firstived  Secondss   Third   age  sibsp  parch     #are embarked  class  \
# 0          0         3    male  22.0      1      0   7.2500        S  Third
# 1          1         1  female  38.0      1      0  71.2833        C  First
# 2          1         3  female  26.0      0      0   7.9250        S  Third
# 3          1         1  female  35.0      1      0  53.1000        S  First
# 4          0         3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Querying a DataFrame

# %%
df = pd.read_csv('../python_introduction/data/titanic.csv')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df['pclass'] > 1
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: pclass, Length: 891, dtype: bool

# %%
only_gold = df.where(df['pclass'] > 2)
only_gold.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch   fare embarked  class    who  \
# 0       0.0     3.0    male  22.0    1.0    0.0  7.250        S  Third    man
# 1       NaN     NaN     NaN   NaN    NaN    NaN    NaN      NaN    NaN    NaN
# 2       1.0     3.0  female  26.0    0.0    0.0  7.925        S  Third  woman
# 3       NaN     NaN     NaN   NaN    NaN    NaN    NaN      NaN    NaN    NaN
# 4       0.0     3.0    male  35.0    0.0    0.0  8.050        S  Third    man
#
#   adult_male deck  embark_town alive  alone
# 0       True  NaN  Southampton    no  False
# 1        NaN  NaN          NaN   NaN    NaN
# 2      False  NaN  Southampton   yes   True
# 3        NaN  NaN          NaN   NaN    NaN
# 4       True  NaN  Southampton    no   True

# %%
only_gold['pclass'].count()
# Out:
# 491

# %%
df['pclass'].count()
# Out:
# 891

# %%
only_gold = only_gold.dropna()
only_gold.head()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 10        1.0     3.0  female   4.0    1.0    1.0  16.7000        S  Third
# 75        0.0     3.0    male  25.0    0.0    0.0   7.6500        S  Third
# 205       0.0     3.0  female   2.0    0.0    1.0  10.4625        S  Third
# 251       0.0     3.0  female  29.0    1.0    1.0  10.4625        S  Third
# 394       1.0     3.0  female  24.0    0.0    2.0  16.7000        S  Third
#
#        who adult_male deck  embark_town alive  alone
# 10   child      False    G  Southampton   yes  False
# 75     man       True    F  Southampton    no   True
# 205  child      False    G  Southampton    no  False
# 251  woman      False    G  Southampton    no  False
# 394  woman      False    G  Southampton   yes  False

# %%
only_gold = df[df['pclass'] > 1]
only_gold.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
# 7         0       3    male   2.0      3      1  21.0750        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 2  woman       False  NaN  Southampton   yes   True
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# 7  child       False  NaN  Southampton    no  False

# %%
len(df[(df['pclass'] > 1) | (df['pclass'] < 3)])
# Out:
# 891

# %%
df[(df['pclass'] > 1) & (df['pclass'] == 2)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 15          1       2  female  55.0      0      0  16.0000        S  Second
# 17          1       2    male   NaN      0      0  13.0000        S  Second
# 20          0       2    male  35.0      0      0  26.0000        S  Second
# 21          1       2    male  34.0      0      0  13.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 866         1       2  female  27.0      1      0  13.8583        C  Second
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 886         0       2    male  27.0      0      0  13.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 9    child       False  NaN    Cherbourg   yes  False
# 15   woman       False  NaN  Southampton   yes   True
# 17     man        True  NaN  Southampton   yes   True
# 20     man        True  NaN  Southampton    no   True
# 21     man        True    D  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 866  woman       False  NaN    Cherbourg   yes  False
# 874  woman       False  NaN    Cherbourg   yes  False
# 880  woman       False  NaN  Southampton   yes  False
# 883    man        True  NaN  Southampton    no   True
# 886    man        True  NaN  Southampton    no   True
#
# [184 rows x 15 columns]

# %% [markdown]
# # Indexing Dataframes

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df['country'] = df.index
df = df.set_index('pclass')
df.head()
# Out:
#         survived     sex   age  sibsp  parch     fare embarked  class    who  \
# pclass
# 3              0    male  22.0      1      0   7.2500        S  Third    man
# 1              1  female  38.0      1      0  71.2833        C  First  woman
# 3              1  female  26.0      0      0   7.9250        S  Third  woman
# 1              1  female  35.0      1      0  53.1000        S  First  woman
# 3              0    male  35.0      0      0   8.0500        S  Third    man
#
#         adult_male deck  embark_town alive  alone  country
# pclass
# 3             True  NaN  Southampton    no  False        0
# 1            False    C    Cherbourg   yes  False        1
# 3            False  NaN  Southampton   yes   True        2
# 1            False    C  Southampton   yes  False        3
# 3             True  NaN  Southampton    no   True        4

# %%
df = df.reset_index()
df.head()
# Out:
#    pclass  survived     sex   age  sibsp  parch     fare embarked  class  \
# 0       3         0    male  22.0      1      0   7.2500        S  Third
# 1       1         1  female  38.0      1      0  71.2833        C  First
# 2       3         1  female  26.0      0      0   7.9250        S  Third
# 3       1         1  female  35.0      1      0  53.1000        S  First
# 4       3         0    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  country
# 0    man        True  NaN  Southampton    no  False        0
# 1  woman       False    C    Cherbourg   yes  False        1
# 2  woman       False  NaN  Southampton   yes   True        2
# 3  woman       False    C  Southampton   yes  False        3
# 4    man        True  NaN  Southampton    no   True        4

# %%
df = pd.read_csv('../python_introduction/data/titanic.csv')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df['pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
df=df[df['pclass'] == 1]
df.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 11         1       1  female  58.0      0      0  26.5500        S  First
# 23         1       1    male  28.0      0      0  35.5000        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 3   woman       False    C  Southampton   yes  False
# 6     man        True    E  Southampton    no   True
# 11  woman       False    C  Southampton   yes   True
# 23    man        True    A  Southampton   yes   True

# %%
columns_to_keep = ['pclass',
                   'sex',
                   'age']
df = df[columns_to_keep]
df.head()
# Out:
#     pclass     sex   age
# 1        1  female  38.0
# 3        1  female  35.0
# 6        1    male  54.0
# 11       1  female  58.0
# 23       1    male  28.0

# %%
df = df.set_index(['pclass', 'sex'])
df.head()
# Out:
#                 age
# pclass sex
# 1      female  38.0
#        female  35.0
#        male    54.0
#        female  58.0
#        male    28.0

# %%
df.loc[1,'female']
# Out:
# /tmp/ipykernel_16526/3404599107.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df.loc[1,'female']
#                 age
# pclass sex
# 1      female  38.0
#        female  35.0
#        female  58.0
#        female   NaN
#        female  49.0
# ...             ...
#        female  45.0
#        female  48.0
#        female  47.0
#        female  56.0
#        female  19.0
#
# [94 rows x 1 columns]

# %%
df.loc[ [(1, 'female'),
         (1, 'male')] ]
# Out:
#                 age
# pclass sex
# 1      female  38.0
#        female  35.0
#        female  58.0
#        female   NaN
#        female  49.0
# ...             ...
#        male     NaN
#        male    51.0
#        male    31.0
#        male    33.0
#        male    26.0
#
# [216 rows x 1 columns]

# %% [markdown]
# # Missing values

# %%
df = pd.read_csv('../python_introduction/data/titanic.csv')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df.fillna?

# %%
df = df.set_index('pclass')
df = df.sort_index()
df
# Out:
#         survived     sex   age  sibsp  parch      fare embarked  class    who  \
# pclass
# 1              1    male   4.0      0      2   81.8583        S  First  child
# 1              1  female  24.0      0      0   83.1583        C  First  woman
# 1              1  female  30.0      0      0   56.9292        C  First  woman
# 1              1  female  17.0      1      0  108.9000        C  First  woman
# 1              1  female   NaN      0      0  110.8833        C  First  woman
# ...          ...     ...   ...    ...    ...       ...      ...    ...    ...
# 3              0    male  19.0      0      0    7.7750        S  Third    man
# 3              1  female   1.0      0      2   15.7417        C  Third  child
# 3              0    male  32.0      0      0    7.9250        S  Third    man
# 3              0    male  18.0      1      0    6.4958        S  Third    man
# 3              0    male  32.0      0      0    7.7500        Q  Third    man
#
#         adult_male deck  embark_town alive  alone
# pclass
# 1            False    A  Southampton   yes  False
# 1            False    C    Cherbourg   yes   True
# 1            False    E    Cherbourg   yes   True
# 1            False    C    Cherbourg   yes  False
# 1            False  NaN    Cherbourg   yes   True
# ...            ...  ...          ...   ...    ...
# 3             True  NaN  Southampton    no   True
# 3            False  NaN    Cherbourg   yes  False
# 3             True  NaN  Southampton    no   True
# 3             True  NaN  Southampton    no  False
# 3             True  NaN   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
df = df.reset_index()
df = df.set_index(['pclass', 'sex'])
df
# Out:
#                survived   age  sibsp  parch      fare embarked  class    who  \
# pclass sex
# 1      male           1   4.0      0      2   81.8583        S  First  child
#        female         1  24.0      0      0   83.1583        C  First  woman
#        female         1  30.0      0      0   56.9292        C  First  woman
#        female         1  17.0      1      0  108.9000        C  First  woman
#        female         1   NaN      0      0  110.8833        C  First  woman
# ...                 ...   ...    ...    ...       ...      ...    ...    ...
# 3      male           0  19.0      0      0    7.7750        S  Third    man
#        female         1   1.0      0      2   15.7417        C  Third  child
#        male           0  32.0      0      0    7.9250        S  Third    man
#        male           0  18.0      1      0    6.4958        S  Third    man
#        male           0  32.0      0      0    7.7500        Q  Third    man
#
#                adult_male deck  embark_town alive  alone
# pclass sex
# 1      male         False    A  Southampton   yes  False
#        female       False    C    Cherbourg   yes   True
#        female       False    E    Cherbourg   yes   True
#        female       False    C    Cherbourg   yes  False
#        female       False  NaN    Cherbourg   yes   True
# ...                   ...  ...          ...   ...    ...
# 3      male          True  NaN  Southampton    no   True
#        female       False  NaN    Cherbourg   yes  False
#        male          True  NaN  Southampton    no   True
#        male          True  NaN  Southampton    no  False
#        male          True  NaN   Queenstown    no   True
#
# [891 rows x 13 columns]

# %%
df = df.fillna(method='ffill')
df.head()
# Out:
#                survived   age  sibsp  parch      fare embarked  class    who  \
# pclass sex
# 1      male           1   4.0      0      2   81.8583        S  First  child
#        female         1  24.0      0      0   83.1583        C  First  woman
#        female         1  30.0      0      0   56.9292        C  First  woman
#        female         1  17.0      1      0  108.9000        C  First  woman
#        female         1  17.0      0      0  110.8833        C  First  woman
#
#                adult_male deck  embark_town alive  alone
# pclass sex
# 1      male         False    A  Southampton   yes  False
#        female       False    C    Cherbourg   yes   True
#        female       False    E    Cherbourg   yes   True
#        female       False    C    Cherbourg   yes  False
#        female       False    C    Cherbourg   yes   True
